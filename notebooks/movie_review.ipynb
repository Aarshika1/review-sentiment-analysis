# %% [markdown]
# # Notebook Set-up

# %%
import pandas as pd
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import matplotlib.pyplot as plt
from collections import Counter

# %% [markdown]
# # Raw Data

# %%
raw_data = pd.read_csv(r'C:\Users\ibrah\Desktop\Projects\review-sentiment-analysis\data\IMDB Dataset.csv')

# %%
raw_data
# Out:
#                                                   review sentiment
# 0      One of the other reviewers has mentioned that ...  positive
# 1      A wonderful little production. <br /><br />The...  positive
# 2      I thought this was a wonderful way to spend ti...  positive
# 3      Basically there's a family where a little boy ...  negative
# 4      Petter Mattei's "Love in the Time of Money" is...  positive
# ...                                                  ...       ...
# 49995  I thought this movie did a down right good job...  positive
# 49996  Bad plot, bad dialogue, bad acting, idiotic di...  negative
# 49997  I am a Catholic taught in parochial elementary...  negative
# 49998  I'm going to have to disagree with the previou...  negative
# 49999  No one expects the Star Trek movies to be high...  negative
#
# [50000 rows x 2 columns]

# %% [markdown]
# # Exploratory analysis

# %%
# Get info about the dataset
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   review     50000 non-null  object
#  1   sentiment  50000 non-null  object
# dtypes: object(2)
# memory usage: 781.4+ KB

# %%
# Check for missing values
raw_data.isnull().sum()
# Out:
# review       0
# sentiment    0
# dtype: int64

# %%
# Get basic statistics
raw_data.describe(include='all')
# Out:
#                                                    review sentiment
# count                                               50000     50000
# unique                                              49582         2
# top     Loved today's show!!! It was a variety and not...  positive
# freq                                                    5     25000

# %%
# Check sentiment distribution
raw_data['sentiment'].value_counts()
# Out:
# sentiment
# positive    25000
# negative    25000
# Name: count, dtype: int64

# %% [markdown]
# # Cleaning

# %%
import logging

# Set up basic logging configuration
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# %%
# Function to clean the text data (removing punctiation, lowercase, lemmaisation and removing stopwords)
nltk.download("stopwords")
nltk.download("wordnet")

def preprocess(text):
    text = re.sub(r"[^a-zA-Z]", " ", text).lower()
    logging.info(f"Lowercase done")
    tokens = text.split()
    tokens = [t for t in tokens if t not in stopwords.words("english")]
    logging.info(f"Lowercase done")
    lemmatizer = WordNetLemmatizer()
    tokens = [lemmatizer.lemmatize(t) for t in tokens]
    logging.info(f"lemmarisation done")
    
    return " ".join(tokens)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ibrah\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\ibrah\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
# Apply the cleaning function to the review column
# cleaned_data = raw_data.copy()
# cleaned_data['review'] = cleaned_data['review'].apply(preprocess)
# cleaned_data
# Out:
# 2025-05-24 22:38:59,415 - INFO - Lowercase done
# 2025-05-24 22:38:59,457 - INFO - Lowercase done
# 2025-05-24 22:38:59,458 - INFO - lemmarisation done
# 2025-05-24 22:38:59,458 - INFO - Lowercase done
# 2025-05-24 22:38:59,480 - INFO - Lowercase done
# 2025-05-24 22:38:59,481 - INFO - lemmarisation done
# 2025-05-24 22:38:59,481 - INFO - Lowercase done
# 2025-05-24 22:38:59,503 - INFO - Lowercase done
# 2025-05-24 22:38:59,504 - INFO - lemmarisation done
# 2025-05-24 22:38:59,504 - INFO - Lowercase done
# 2025-05-24 22:38:59,523 - INFO - Lowercase done
# 2025-05-24 22:38:59,523 - INFO - lemmarisation done
# 2025-05-24 22:38:59,524 - INFO - Lowercase done
# 2025-05-24 22:38:59,555 - INFO - Lowercase done
# 2025-05-24 22:38:59,556 - INFO - lemmarisation done
# 2025-05-24 22:38:59,556 - INFO - Lowercase done
# 2025-05-24 22:38:59,573 - INFO - Lowercase done
# 2025-05-24 22:38:59,574 - INFO - lemmarisation done
# 2025-05-24 22:38:59,574 - INFO - Lowercase done
# 2025-05-24 22:38:59,597 - INFO - Lowercase done
# 2025-05-24 22:38:59,597 - INFO - lemmarisation done
# 2025-05-24 22:38:59,598 - INFO - Lowercase done
# 2025-05-24 22:38:59,621 - INFO - Lowercase done
# 2025-05-24 22:38:59,622 - INFO - lemmarisation done
# 2025-05-24 22:38:59,622 - INFO - Lowercase done
# 2025-05-24 22:38:59,640 - INFO - Lowercase done
# 2025-05-24 22:38:59,641 - INFO - lemmarisation done
# 2025-05-24 22:38:59,641 - INFO - Lowercase done
# 2025-05-24 22:38:59,647 - INFO - Lowercase done
# 2025-05-24 22:38:59,648 - INFO - lemmarisation done
# 2025-05-24 22:38:59,648 - INFO - Lowercase done
# 2025-05-24 22:38:59,662 - INFO - Lowercase done
# 2025-05-24 22:38:59,663 - INFO - lemmarisation done
# 2025-05-24 22:38:59,663 - INFO - Lowercase done
# 2025-05-24 22:38:59,688 - INFO - Lowercase done
# 2025-05-24 22:38:59,689 - INFO - lemmarisation done
# 2025-05-24 22:38:59,689 - INFO - Lowercase done
# 2025-05-24 22:38:59,741 - INFO - Lowercase done
# 2025-05-24 22:38:59,743 - INFO - lemmarisation done
# 2025-05-24 22:38:59,743 - INFO - Lowercase done
# 2025-05-24 22:38:59,759 - INFO - Lowercase done
# 2025-05-24 22:38:59,760 - INFO - lemmarisation done
# 2025-05-24 22:38:59,761 - INFO - Lowercase done
# 2025-05-24 22:38:59,768 - INFO - Lowercase done
# 2025-05-24 22:38:59,768 - INFO - lemmarisation done
# 2025-05-24 22:38:59,769 - INFO - Lowercase done
# 2025-05-24 22:38:59,787 - INFO - Lowercase done
# 2025-05-24 22:38:59,788 - INFO - lemmarisation done
# 2025-05-24 22:38:59,788 - INFO - Lowercase done
# 2025-05-24 22:38:59,808 - INFO - Lowercase done
# 2025-05-24 22:38:59,808 - INFO - lemmarisation done
# 2025-05-24 22:38:59,809 - INFO - Lowercase done
# 2025-05-24 22:38:59,839 - INFO - Lowercase done
# 2025-05-24 22:38:59,840 - INFO - lemmarisation done
# 2025-05-24 22:38:59,841 - INFO - Lowercase done
# 2025-05-24 22:38:59,857 - INFO - Lowercase done
# 2025-05-24 22:38:59,858 - INFO - lemmarisation done
# 2025-05-24 22:38:59,859 - INFO - Lowercase done
# 2025-05-24 22:38:59,877 - INFO - Lowercase done
# 2025-05-24 22:38:59,878 - INFO - lemmarisation done
# 2025-05-24 22:38:59,878 - INFO - Lowercase done
# 2025-05-24 22:38:59,921 - INFO - Lowercase done
# 2025-05-24 22:38:59,922 - INFO - lemmarisation done
# 2025-05-24 22:38:59,923 - INFO - Lowercase done
# 2025-05-24 22:38:59,948 - INFO - Lowercase done
# 2025-05-24 22:38:59,949 - INFO - lemmarisation done
# 2025-05-24 22:38:59,949 - INFO - Lowercase done
# 2025-05-24 22:38:59,959 - INFO - Lowercase done
# 2025-05-24 22:38:59,960 - INFO - lemmarisation done
# 2025-05-24 22:38:59,960 - INFO - Lowercase done
# 2025-05-24 22:39:00,003 - INFO - Lowercase done
# 2025-05-24 22:39:00,004 - INFO - lemmarisation done
# 2025-05-24 22:39:00,005 - INFO - Lowercase done
# 2025-05-24 22:39:00,026 - INFO - Lowercase done
# 2025-05-24 22:39:00,027 - INFO - lemmarisation done
# 2025-05-24 22:39:00,028 - INFO - Lowercase done
# 2025-05-24 22:39:00,043 - INFO - Lowercase done
# 2025-05-24 22:39:00,044 - INFO - lemmarisation done
# 2025-05-24 22:39:00,045 - INFO - Lowercase done
# 2025-05-24 22:39:00,120 - INFO - Lowercase done
# 2025-05-24 22:39:00,121 - INFO - lemmarisation done
# 2025-05-24 22:39:00,122 - INFO - Lowercase done
# 2025-05-24 22:39:00,141 - INFO - Lowercase done
# 2025-05-24 22:39:00,142 - INFO - lemmarisation done
# 2025-05-24 22:39:00,143 - INFO - Lowercase done
# 2025-05-24 22:39:00,159 - INFO - Lowercase done
# 2025-05-24 22:39:00,160 - INFO - lemmarisation done
# 2025-05-24 22:39:00,160 - INFO - Lowercase done
# 2025-05-24 22:39:00,242 - INFO - Lowercase done
# 2025-05-24 22:39:00,244 - INFO - lemmarisation done
# 2025-05-24 22:39:00,244 - INFO - Lowercase done
# 2025-05-24 22:39:00,298 - INFO - Lowercase done
# 2025-05-24 22:39:00,299 - INFO - lemmarisation done
# 2025-05-24 22:39:00,300 - INFO - Lowercase done
# 2025-05-24 22:39:00,355 - INFO - Lowercase done
# 2025-05-24 22:39:00,356 - INFO - lemmarisation done
# 2025-05-24 22:39:00,357 - INFO - Lowercase done
# 2025-05-24 22:39:00,373 - INFO - Lowercase done
# 2025-05-24 22:39:00,374 - INFO - lemmarisation done
# 2025-05-24 22:39:00,375 - INFO - Lowercase done
# 2025-05-24 22:39:00,460 - INFO - Lowercase done
# 2025-05-24 22:39:00,461 - INFO - lemmarisation done
# 2025-05-24 22:39:00,461 - INFO - Lowercase done
# 2025-05-24 22:39:00,495 - INFO - Lowercase done
# 2025-05-24 22:39:00,496 - INFO - lemmarisation done
# 2025-05-24 22:39:00,496 - INFO - Lowercase done
# 2025-05-24 22:39:00,546 - INFO - Lowercase done
# 2025-05-24 22:39:00,547 - INFO - lemmarisation done
# 2025-05-24 22:39:00,548 - INFO - Lowercase done
# 2025-05-24 22:39:00,563 - INFO - Lowercase done
# 2025-05-24 22:39:00,563 - INFO - lemmarisation done
# 2025-05-24 22:39:00,564 - INFO - Lowercase done
# 2025-05-24 22:39:00,605 - INFO - Lowercase done
# 2025-05-24 22:39:00,606 - INFO - lemmarisation done
# 2025-05-24 22:39:00,607 - INFO - Lowercase done
# 2025-05-24 22:39:00,623 - INFO - Lowercase done
# 2025-05-24 22:39:00,624 - INFO - lemmarisation done
# 2025-05-24 22:39:00,624 - INFO - Lowercase done
# 2025-05-24 22:39:00,659 - INFO - Lowercase done
# 2025-05-24 22:39:00,660 - INFO - lemmarisation done
# 2025-05-24 22:39:00,660 - INFO - Lowercase done
# 2025-05-24 22:39:00,677 - INFO - Lowercase done
# 2025-05-24 22:39:00,678 - INFO - lemmarisation done
# 2025-05-24 22:39:00,678 - INFO - Lowercase done
# 2025-05-24 22:39:00,707 - INFO - Lowercase done
# 2025-05-24 22:39:00,708 - INFO - lemmarisation done
# 2025-05-24 22:39:00,708 - INFO - Lowercase done
# 2025-05-24 22:39:00,731 - INFO - Lowercase done
# 2025-05-24 22:39:00,732 - INFO - lemmarisation done
# 2025-05-24 22:39:00,733 - INFO - Lowercase done
# 2025-05-24 22:39:00,767 - INFO - Lowercase done
# 2025-05-24 22:39:00,768 - INFO - lemmarisation done
# 2025-05-24 22:39:00,768 - INFO - Lowercase done
# 2025-05-24 22:39:00,791 - INFO - Lowercase done
# 2025-05-24 22:39:00,792 - INFO - lemmarisation done
# 2025-05-24 22:39:00,793 - INFO - Lowercase done
# 2025-05-24 22:39:00,823 - INFO - Lowercase done
# 2025-05-24 22:39:00,824 - INFO - lemmarisation done
# 2025-05-24 22:39:00,824 - INFO - Lowercase done
# 2025-05-24 22:39:00,834 - INFO - Lowercase done
# 2025-05-24 22:39:00,835 - INFO - lemmarisation done
# 2025-05-24 22:39:00,836 - INFO - Lowercase done
# 2025-05-24 22:39:00,854 - INFO - Lowercase done
# 2025-05-24 22:39:00,855 - INFO - lemmarisation done
# 2025-05-24 22:39:00,856 - INFO - Lowercase done
# 2025-05-24 22:39:00,946 - INFO - Lowercase done
# 2025-05-24 22:39:00,947 - INFO - lemmarisation done
# 2025-05-24 22:39:00,948 - INFO - Lowercase done
# 2025-05-24 22:39:00,961 - INFO - Lowercase done
# 2025-05-24 22:39:00,962 - INFO - lemmarisation done
# 2025-05-24 22:39:00,963 - INFO - Lowercase done
# 2025-05-24 22:39:01,019 - INFO - Lowercase done
# 2025-05-24 22:39:01,020 - INFO - lemmarisation done
# 2025-05-24 22:39:01,021 - INFO - Lowercase done
# 2025-05-24 22:39:01,101 - INFO - Lowercase done
# 2025-05-24 22:39:01,103 - INFO - lemmarisation done
# 2025-05-24 22:39:01,103 - INFO - Lowercase done
# 2025-05-24 22:39:01,125 - INFO - Lowercase done
# 2025-05-24 22:39:01,126 - INFO - lemmarisation done
# 2025-05-24 22:39:01,126 - INFO - Lowercase done
# 2025-05-24 22:39:01,138 - INFO - Lowercase done
# 2025-05-24 22:39:01,139 - INFO - lemmarisation done
# 2025-05-24 22:39:01,139 - INFO - Lowercase done
# 2025-05-24 22:39:01,165 - INFO - Lowercase done
# 2025-05-24 22:39:01,166 - INFO - lemmarisation done
# 2025-05-24 22:39:01,166 - INFO - Lowercase done
# 2025-05-24 22:39:01,194 - INFO - Lowercase done
# 2025-05-24 22:39:01,194 - INFO - lemmarisation done
# 2025-05-24 22:39:01,195 - INFO - Lowercase done
# 2025-05-24 22:39:01,221 - INFO - Lowercase done
# 2025-05-24 22:39:01,223 - INFO - lemmarisation done
# 2025-05-24 22:39:01,223 - INFO - Lowercase done
# 2025-05-24 22:39:01,249 - INFO - Lowercase done
# 2025-05-24 22:39:01,250 - INFO - lemmarisation done
# 2025-05-24 22:39:01,251 - INFO - Lowercase done
# 2025-05-24 22:39:01,316 - INFO - Lowercase done
# 2025-05-24 22:39:01,318 - INFO - lemmarisation done
# 2025-05-24 22:39:01,318 - INFO - Lowercase done
# 2025-05-24 22:39:01,379 - INFO - Lowercase done
# 2025-05-24 22:39:01,380 - INFO - lemmarisation done
# 2025-05-24 22:39:01,380 - INFO - Lowercase done
# 2025-05-24 22:39:01,402 - INFO - Lowercase done
# 2025-05-24 22:39:01,403 - INFO - lemmarisation done
# 2025-05-24 22:39:01,403 - INFO - Lowercase done
# 2025-05-24 22:39:01,424 - INFO - Lowercase done
# 2025-05-24 22:39:01,425 - INFO - lemmarisation done
# 2025-05-24 22:39:01,426 - INFO - Lowercase done
# 2025-05-24 22:39:01,438 - INFO - Lowercase done
# 2025-05-24 22:39:01,439 - INFO - lemmarisation done
# 2025-05-24 22:39:01,439 - INFO - Lowercase done
# 2025-05-24 22:39:01,446 - INFO - Lowercase done
# 2025-05-24 22:39:01,446 - INFO - lemmarisation done
# 2025-05-24 22:39:01,447 - INFO - Lowercase done
# 2025-05-24 22:39:01,471 - INFO - Lowercase done
# 2025-05-24 22:39:01,472 - INFO - lemmarisation done
# 2025-05-24 22:39:01,472 - INFO - Lowercase done
# 2025-05-24 22:39:01,510 - INFO - Lowercase done
# 2025-05-24 22:39:01,511 - INFO - lemmarisation done
# 2025-05-24 22:39:01,512 - INFO - Lowercase done
# 2025-05-24 22:39:01,557 - INFO - Lowercase done
# 2025-05-24 22:39:01,559 - INFO - lemmarisation done
# 2025-05-24 22:39:01,559 - INFO - Lowercase done
# 2025-05-24 22:39:01,578 - INFO - Lowercase done
# 2025-05-24 22:39:01,579 - INFO - lemmarisation done
# 2025-05-24 22:39:01,579 - INFO - Lowercase done
# 2025-05-24 22:39:01,607 - INFO - Lowercase done
# 2025-05-24 22:39:01,608 - INFO - lemmarisation done
# 2025-05-24 22:39:01,608 - INFO - Lowercase done
# 2025-05-24 22:39:01,649 - INFO - Lowercase done
# 2025-05-24 22:39:01,650 - INFO - lemmarisation done
# 2025-05-24 22:39:01,650 - INFO - Lowercase done
# 2025-05-24 22:39:01,679 - INFO - Lowercase done
# 2025-05-24 22:39:01,680 - INFO - lemmarisation done
# 2025-05-24 22:39:01,680 - INFO - Lowercase done
# 2025-05-24 22:39:01,715 - INFO - Lowercase done
# 2025-05-24 22:39:01,717 - INFO - lemmarisation done
# 2025-05-24 22:39:01,717 - INFO - Lowercase done
# 2025-05-24 22:39:01,750 - INFO - Lowercase done
# 2025-05-24 22:39:01,751 - INFO - lemmarisation done
# 2025-05-24 22:39:01,751 - INFO - Lowercase done
# 2025-05-24 22:39:01,775 - INFO - Lowercase done
# 2025-05-24 22:39:01,776 - INFO - lemmarisation done
# 2025-05-24 22:39:01,776 - INFO - Lowercase done
# 2025-05-24 22:39:01,813 - INFO - Lowercase done
# 2025-05-24 22:39:01,814 - INFO - lemmarisation done
# 2025-05-24 22:39:01,814 - INFO - Lowercase done
# 2025-05-24 22:39:01,835 - INFO - Lowercase done
# 2025-05-24 22:39:01,835 - INFO - lemmarisation done
# 2025-05-24 22:39:01,836 - INFO - Lowercase done
# 2025-05-24 22:39:01,877 - INFO - Lowercase done
# 2025-05-24 22:39:01,878 - INFO - lemmarisation done
# 2025-05-24 22:39:01,878 - INFO - Lowercase done
# 2025-05-24 22:39:01,957 - INFO - Lowercase done
# 2025-05-24 22:39:01,959 - INFO - lemmarisation done
# 2025-05-24 22:39:01,959 - INFO - Lowercase done
# 2025-05-24 22:39:01,977 - INFO - Lowercase done
# 2025-05-24 22:39:01,978 - INFO - lemmarisation done
# 2025-05-24 22:39:01,978 - INFO - Lowercase done
# 2025-05-24 22:39:02,016 - INFO - Lowercase done
# 2025-05-24 22:39:02,017 - INFO - lemmarisation done
# 2025-05-24 22:39:02,018 - INFO - Lowercase done
# 2025-05-24 22:39:02,039 - INFO - Lowercase done
# 2025-05-24 22:39:02,039 - INFO - lemmarisation done
# 2025-05-24 22:39:02,040 - INFO - Lowercase done
# 2025-05-24 22:39:02,061 - INFO - Lowercase done
# 2025-05-24 22:39:02,061 - INFO - lemmarisation done
# 2025-05-24 22:39:02,062 - INFO - Lowercase done
# 2025-05-24 22:39:02,096 - INFO - Lowercase done
# 2025-05-24 22:39:02,097 - INFO - lemmarisation done
# 2025-05-24 22:39:02,097 - INFO - Lowercase done
# 2025-05-24 22:39:02,151 - INFO - Lowercase done
# 2025-05-24 22:39:02,152 - INFO - lemmarisation done
# 2025-05-24 22:39:02,153 - INFO - Lowercase done
# 2025-05-24 22:39:02,163 - INFO - Lowercase done
# 2025-05-24 22:39:02,163 - INFO - lemmarisation done
# 2025-05-24 22:39:02,164 - INFO - Lowercase done
# 2025-05-24 22:39:02,183 - INFO - Lowercase done
# 2025-05-24 22:39:02,184 - INFO - lemmarisation done
# 2025-05-24 22:39:02,184 - INFO - Lowercase done
# 2025-05-24 22:39:02,223 - INFO - Lowercase done
# 2025-05-24 22:39:02,224 - INFO - lemmarisation done
# 2025-05-24 22:39:02,224 - INFO - Lowercase done
# 2025-05-24 22:39:02,242 - INFO - Lowercase done
# 2025-05-24 22:39:02,243 - INFO - lemmarisation done
# 2025-05-24 22:39:02,243 - INFO - Lowercase done
# 2025-05-24 22:39:02,268 - INFO - Lowercase done
# 2025-05-24 22:39:02,269 - INFO - lemmarisation done
# 2025-05-24 22:39:02,269 - INFO - Lowercase done
# 2025-05-24 22:39:02,315 - INFO - Lowercase done
# 2025-05-24 22:39:02,317 - INFO - lemmarisation done
# 2025-05-24 22:39:02,317 - INFO - Lowercase done
# 2025-05-24 22:39:02,340 - INFO - Lowercase done
# 2025-05-24 22:39:02,341 - INFO - lemmarisation done
# 2025-05-24 22:39:02,342 - INFO - Lowercase done
# 2025-05-24 22:39:02,368 - INFO - Lowercase done
# 2025-05-24 22:39:02,369 - INFO - lemmarisation done
# 2025-05-24 22:39:02,369 - INFO - Lowercase done
# 2025-05-24 22:39:02,421 - INFO - Lowercase done
# 2025-05-24 22:39:02,422 - INFO - lemmarisation done
# 2025-05-24 22:39:02,422 - INFO - Lowercase done
# 2025-05-24 22:39:02,445 - INFO - Lowercase done
# 2025-05-24 22:39:02,445 - INFO - lemmarisation done
# 2025-05-24 22:39:02,446 - INFO - Lowercase done
# 2025-05-24 22:39:02,465 - INFO - Lowercase done
# 2025-05-24 22:39:02,466 - INFO - lemmarisation done
# 2025-05-24 22:39:02,467 - INFO - Lowercase done
# 2025-05-24 22:39:02,503 - INFO - Lowercase done
# 2025-05-24 22:39:02,504 - INFO - lemmarisation done
# 2025-05-24 22:39:02,505 - INFO - Lowercase done
# 2025-05-24 22:39:02,529 - INFO - Lowercase done
# 2025-05-24 22:39:02,530 - INFO - lemmarisation done
# 2025-05-24 22:39:02,531 - INFO - Lowercase done
# 2025-05-24 22:39:02,548 - INFO - Lowercase done
# 2025-05-24 22:39:02,549 - INFO - lemmarisation done
# 2025-05-24 22:39:02,549 - INFO - Lowercase done
# 2025-05-24 22:39:02,574 - INFO - Lowercase done
# 2025-05-24 22:39:02,575 - INFO - lemmarisation done
# 2025-05-24 22:39:02,576 - INFO - Lowercase done
# 2025-05-24 22:39:02,642 - INFO - Lowercase done
# 2025-05-24 22:39:02,643 - INFO - lemmarisation done
# 2025-05-24 22:39:02,643 - INFO - Lowercase done
# 2025-05-24 22:39:02,662 - INFO - Lowercase done
# 2025-05-24 22:39:02,663 - INFO - lemmarisation done
# 2025-05-24 22:39:02,664 - INFO - Lowercase done
# 2025-05-24 22:39:02,762 - INFO - Lowercase done
# 2025-05-24 22:39:02,763 - INFO - lemmarisation done
# 2025-05-24 22:39:02,764 - INFO - Lowercase done
# 2025-05-24 22:39:02,784 - INFO - Lowercase done
# 2025-05-24 22:39:02,785 - INFO - lemmarisation done
# 2025-05-24 22:39:02,785 - INFO - Lowercase done
# 2025-05-24 22:39:02,825 - INFO - Lowercase done
# 2025-05-24 22:39:02,826 - INFO - lemmarisation done
# 2025-05-24 22:39:02,826 - INFO - Lowercase done
# 2025-05-24 22:39:02,850 - INFO - Lowercase done
# 2025-05-24 22:39:02,851 - INFO - lemmarisation done
# 2025-05-24 22:39:02,851 - INFO - Lowercase done
# 2025-05-24 22:39:02,878 - INFO - Lowercase done
# 2025-05-24 22:39:02,879 - INFO - lemmarisation done
# 2025-05-24 22:39:02,879 - INFO - Lowercase done
# 2025-05-24 22:39:02,894 - INFO - Lowercase done
# 2025-05-24 22:39:02,895 - INFO - lemmarisation done
# 2025-05-24 22:39:02,895 - INFO - Lowercase done
# 2025-05-24 22:39:02,935 - INFO - Lowercase done
# 2025-05-24 22:39:02,936 - INFO - lemmarisation done
# 2025-05-24 22:39:02,936 - INFO - Lowercase done
# 2025-05-24 22:39:02,960 - INFO - Lowercase done
# 2025-05-24 22:39:02,961 - INFO - lemmarisation done
# 2025-05-24 22:39:02,961 - INFO - Lowercase done
# 2025-05-24 22:39:02,977 - INFO - Lowercase done
# 2025-05-24 22:39:02,978 - INFO - lemmarisation done
# 2025-05-24 22:39:02,978 - INFO - Lowercase done
# 2025-05-24 22:39:02,997 - INFO - Lowercase done
# 2025-05-24 22:39:02,998 - INFO - lemmarisation done
# 2025-05-24 22:39:02,998 - INFO - Lowercase done
# 2025-05-24 22:39:03,024 - INFO - Lowercase done
# 2025-05-24 22:39:03,025 - INFO - lemmarisation done
# 2025-05-24 22:39:03,025 - INFO - Lowercase done
# 2025-05-24 22:39:03,032 - INFO - Lowercase done
# 2025-05-24 22:39:03,032 - INFO - lemmarisation done
# 2025-05-24 22:39:03,033 - INFO - Lowercase done
# 2025-05-24 22:39:03,046 - INFO - Lowercase done
# 2025-05-24 22:39:03,046 - INFO - lemmarisation done
# 2025-05-24 22:39:03,047 - INFO - Lowercase done
# 2025-05-24 22:39:03,080 - INFO - Lowercase done
# 2025-05-24 22:39:03,082 - INFO - lemmarisation done
# 2025-05-24 22:39:03,082 - INFO - Lowercase done
# 2025-05-24 22:39:03,099 - INFO - Lowercase done
# 2025-05-24 22:39:03,100 - INFO - lemmarisation done
# 2025-05-24 22:39:03,101 - INFO - Lowercase done
# 2025-05-24 22:39:03,145 - INFO - Lowercase done
# 2025-05-24 22:39:03,146 - INFO - lemmarisation done
# 2025-05-24 22:39:03,147 - INFO - Lowercase done
# 2025-05-24 22:39:03,158 - INFO - Lowercase done
# 2025-05-24 22:39:03,159 - INFO - lemmarisation done
# 2025-05-24 22:39:03,159 - INFO - Lowercase done
# 2025-05-24 22:39:03,172 - INFO - Lowercase done
# 2025-05-24 22:39:03,173 - INFO - lemmarisation done
# 2025-05-24 22:39:03,173 - INFO - Lowercase done
# 2025-05-24 22:39:03,213 - INFO - Lowercase done
# 2025-05-24 22:39:03,214 - INFO - lemmarisation done
# 2025-05-24 22:39:03,215 - INFO - Lowercase done
# 2025-05-24 22:39:03,231 - INFO - Lowercase done
# 2025-05-24 22:39:03,232 - INFO - lemmarisation done
# 2025-05-24 22:39:03,232 - INFO - Lowercase done
# 2025-05-24 22:39:03,255 - INFO - Lowercase done
# 2025-05-24 22:39:03,256 - INFO - lemmarisation done
# 2025-05-24 22:39:03,256 - INFO - Lowercase done
# 2025-05-24 22:39:03,283 - INFO - Lowercase done
# 2025-05-24 22:39:03,284 - INFO - lemmarisation done
# 2025-05-24 22:39:03,285 - INFO - Lowercase done
# 2025-05-24 22:39:03,304 - INFO - Lowercase done
# 2025-05-24 22:39:03,305 - INFO - lemmarisation done
# 2025-05-24 22:39:03,306 - INFO - Lowercase done
# 2025-05-24 22:39:03,324 - INFO - Lowercase done
# 2025-05-24 22:39:03,325 - INFO - lemmarisation done
# 2025-05-24 22:39:03,326 - INFO - Lowercase done
# 2025-05-24 22:39:03,342 - INFO - Lowercase done
# 2025-05-24 22:39:03,343 - INFO - lemmarisation done
# 2025-05-24 22:39:03,343 - INFO - Lowercase done
# 2025-05-24 22:39:03,396 - INFO - Lowercase done
# 2025-05-24 22:39:03,397 - INFO - lemmarisation done
# 2025-05-24 22:39:03,397 - INFO - Lowercase done
# 2025-05-24 22:39:03,414 - INFO - Lowercase done
# 2025-05-24 22:39:03,415 - INFO - lemmarisation done
# 2025-05-24 22:39:03,416 - INFO - Lowercase done
# 2025-05-24 22:39:03,443 - INFO - Lowercase done
# 2025-05-24 22:39:03,444 - INFO - lemmarisation done
# 2025-05-24 22:39:03,444 - INFO - Lowercase done
# 2025-05-24 22:39:03,461 - INFO - Lowercase done
# 2025-05-24 22:39:03,462 - INFO - lemmarisation done
# 2025-05-24 22:39:03,462 - INFO - Lowercase done
# 2025-05-24 22:39:03,488 - INFO - Lowercase done
# 2025-05-24 22:39:03,489 - INFO - lemmarisation done
# 2025-05-24 22:39:03,489 - INFO - Lowercase done
# 2025-05-24 22:39:03,545 - INFO - Lowercase done
# 2025-05-24 22:39:03,546 - INFO - lemmarisation done
# 2025-05-24 22:39:03,546 - INFO - Lowercase done
# 2025-05-24 22:39:03,569 - INFO - Lowercase done
# 2025-05-24 22:39:03,569 - INFO - lemmarisation done
# 2025-05-24 22:39:03,570 - INFO - Lowercase done
# 2025-05-24 22:39:03,586 - INFO - Lowercase done
# 2025-05-24 22:39:03,587 - INFO - lemmarisation done
# 2025-05-24 22:39:03,587 - INFO - Lowercase done
# 2025-05-24 22:39:03,613 - INFO - Lowercase done
# 2025-05-24 22:39:03,614 - INFO - lemmarisation done
# 2025-05-24 22:39:03,614 - INFO - Lowercase done
# 2025-05-24 22:39:03,668 - INFO - Lowercase done
# 2025-05-24 22:39:03,669 - INFO - lemmarisation done
# 2025-05-24 22:39:03,669 - INFO - Lowercase done
# 2025-05-24 22:39:03,683 - INFO - Lowercase done
# 2025-05-24 22:39:03,684 - INFO - lemmarisation done
# 2025-05-24 22:39:03,684 - INFO - Lowercase done
# 2025-05-24 22:39:03,717 - INFO - Lowercase done
# 2025-05-24 22:39:03,718 - INFO - lemmarisation done
# 2025-05-24 22:39:03,718 - INFO - Lowercase done
# 2025-05-24 22:39:03,755 - INFO - Lowercase done
# 2025-05-24 22:39:03,756 - INFO - lemmarisation done
# 2025-05-24 22:39:03,756 - INFO - Lowercase done
# 2025-05-24 22:39:03,791 - INFO - Lowercase done
# 2025-05-24 22:39:03,792 - INFO - lemmarisation done
# 2025-05-24 22:39:03,793 - INFO - Lowercase done
# 2025-05-24 22:39:03,843 - INFO - Lowercase done
# 2025-05-24 22:39:03,844 - INFO - lemmarisation done
# 2025-05-24 22:39:03,845 - INFO - Lowercase done
# 2025-05-24 22:39:03,882 - INFO - Lowercase done
# 2025-05-24 22:39:03,883 - INFO - lemmarisation done
# 2025-05-24 22:39:03,884 - INFO - Lowercase done
# 2025-05-24 22:39:03,967 - INFO - Lowercase done
# 2025-05-24 22:39:03,968 - INFO - lemmarisation done
# 2025-05-24 22:39:03,968 - INFO - Lowercase done
# 2025-05-24 22:39:03,980 - INFO - Lowercase done
# 2025-05-24 22:39:03,980 - INFO - lemmarisation done
# 2025-05-24 22:39:03,981 - INFO - Lowercase done
# 2025-05-24 22:39:04,013 - INFO - Lowercase done
# 2025-05-24 22:39:04,014 - INFO - lemmarisation done
# 2025-05-24 22:39:04,015 - INFO - Lowercase done
# 2025-05-24 22:39:04,054 - INFO - Lowercase done
# 2025-05-24 22:39:04,055 - INFO - lemmarisation done
# 2025-05-24 22:39:04,055 - INFO - Lowercase done
# 2025-05-24 22:39:04,084 - INFO - Lowercase done
# 2025-05-24 22:39:04,085 - INFO - lemmarisation done
# 2025-05-24 22:39:04,085 - INFO - Lowercase done
# 2025-05-24 22:39:04,124 - INFO - Lowercase done
# 2025-05-24 22:39:04,125 - INFO - lemmarisation done
# 2025-05-24 22:39:04,126 - INFO - Lowercase done
# 2025-05-24 22:39:04,144 - INFO - Lowercase done
# 2025-05-24 22:39:04,145 - INFO - lemmarisation done
# 2025-05-24 22:39:04,145 - INFO - Lowercase done
# 2025-05-24 22:39:04,183 - INFO - Lowercase done
# 2025-05-24 22:39:04,184 - INFO - lemmarisation done
# 2025-05-24 22:39:04,185 - INFO - Lowercase done
# 2025-05-24 22:39:04,206 - INFO - Lowercase done
# 2025-05-24 22:39:04,207 - INFO - lemmarisation done
# 2025-05-24 22:39:04,207 - INFO - Lowercase done
# 2025-05-24 22:39:04,232 - INFO - Lowercase done
# 2025-05-24 22:39:04,233 - INFO - lemmarisation done
# 2025-05-24 22:39:04,234 - INFO - Lowercase done
# 2025-05-24 22:39:04,258 - INFO - Lowercase done
# 2025-05-24 22:39:04,259 - INFO - lemmarisation done
# 2025-05-24 22:39:04,259 - INFO - Lowercase done
# 2025-05-24 22:39:04,284 - INFO - Lowercase done
# 2025-05-24 22:39:04,285 - INFO - lemmarisation done
# 2025-05-24 22:39:04,286 - INFO - Lowercase done
# 2025-05-24 22:39:04,312 - INFO - Lowercase done
# 2025-05-24 22:39:04,313 - INFO - lemmarisation done
# 2025-05-24 22:39:04,313 - INFO - Lowercase done
# 2025-05-24 22:39:04,325 - INFO - Lowercase done
# 2025-05-24 22:39:04,326 - INFO - lemmarisation done
# 2025-05-24 22:39:04,327 - INFO - Lowercase done
# 2025-05-24 22:39:04,433 - INFO - Lowercase done
# 2025-05-24 22:39:04,435 - INFO - lemmarisation done
# 2025-05-24 22:39:04,436 - INFO - Lowercase done
# 2025-05-24 22:39:04,455 - INFO - Lowercase done
# 2025-05-24 22:39:04,455 - INFO - lemmarisation done
# 2025-05-24 22:39:04,456 - INFO - Lowercase done
# 2025-05-24 22:39:04,474 - INFO - Lowercase done
# 2025-05-24 22:39:04,475 - INFO - lemmarisation done
# 2025-05-24 22:39:04,475 - INFO - Lowercase done
# 2025-05-24 22:39:04,491 - INFO - Lowercase done
# 2025-05-24 22:39:04,492 - INFO - lemmarisation done
# 2025-05-24 22:39:04,492 - INFO - Lowercase done
# 2025-05-24 22:39:04,500 - INFO - Lowercase done
# 2025-05-24 22:39:04,501 - INFO - lemmarisation done
# 2025-05-24 22:39:04,501 - INFO - Lowercase done
# 2025-05-24 22:39:04,529 - INFO - Lowercase done
# 2025-05-24 22:39:04,529 - INFO - lemmarisation done
# 2025-05-24 22:39:04,530 - INFO - Lowercase done
# 2025-05-24 22:39:04,540 - INFO - Lowercase done
# 2025-05-24 22:39:04,540 - INFO - lemmarisation done
# 2025-05-24 22:39:04,541 - INFO - Lowercase done
# 2025-05-24 22:39:04,603 - INFO - Lowercase done
# 2025-05-24 22:39:04,604 - INFO - lemmarisation done
# 2025-05-24 22:39:04,605 - INFO - Lowercase done
# 2025-05-24 22:39:04,654 - INFO - Lowercase done
# 2025-05-24 22:39:04,655 - INFO - lemmarisation done
# 2025-05-24 22:39:04,655 - INFO - Lowercase done
# 2025-05-24 22:39:04,666 - INFO - Lowercase done
# 2025-05-24 22:39:04,666 - INFO - lemmarisation done
# 2025-05-24 22:39:04,667 - INFO - Lowercase done
# 2025-05-24 22:39:04,683 - INFO - Lowercase done
# 2025-05-24 22:39:04,684 - INFO - lemmarisation done
# 2025-05-24 22:39:04,684 - INFO - Lowercase done
# 2025-05-24 22:39:04,715 - INFO - Lowercase done
# 2025-05-24 22:39:04,716 - INFO - lemmarisation done
# 2025-05-24 22:39:04,716 - INFO - Lowercase done
# 2025-05-24 22:39:04,732 - INFO - Lowercase done
# 2025-05-24 22:39:04,733 - INFO - lemmarisation done
# 2025-05-24 22:39:04,733 - INFO - Lowercase done
# 2025-05-24 22:39:04,780 - INFO - Lowercase done
# 2025-05-24 22:39:04,781 - INFO - lemmarisation done
# 2025-05-24 22:39:04,782 - INFO - Lowercase done
# 2025-05-24 22:39:04,815 - INFO - Lowercase done
# 2025-05-24 22:39:04,816 - INFO - lemmarisation done
# 2025-05-24 22:39:04,817 - INFO - Lowercase done
# 2025-05-24 22:39:04,837 - INFO - Lowercase done
# 2025-05-24 22:39:04,838 - INFO - lemmarisation done
# 2025-05-24 22:39:04,839 - INFO - Lowercase done
# 2025-05-24 22:39:04,919 - INFO - Lowercase done
# 2025-05-24 22:39:04,920 - INFO - lemmarisation done
# 2025-05-24 22:39:04,920 - INFO - Lowercase done
# 2025-05-24 22:39:04,970 - INFO - Lowercase done
# 2025-05-24 22:39:04,971 - INFO - lemmarisation done
# 2025-05-24 22:39:04,972 - INFO - Lowercase done
# 2025-05-24 22:39:05,011 - INFO - Lowercase done
# 2025-05-24 22:39:05,012 - INFO - lemmarisation done
# 2025-05-24 22:39:05,012 - INFO - Lowercase done
# 2025-05-24 22:39:05,049 - INFO - Lowercase done
# 2025-05-24 22:39:05,050 - INFO - lemmarisation done
# 2025-05-24 22:39:05,051 - INFO - Lowercase done
# 2025-05-24 22:39:05,080 - INFO - Lowercase done
# 2025-05-24 22:39:05,081 - INFO - lemmarisation done
# 2025-05-24 22:39:05,081 - INFO - Lowercase done
# 2025-05-24 22:39:05,181 - INFO - Lowercase done
# 2025-05-24 22:39:05,182 - INFO - lemmarisation done
# 2025-05-24 22:39:05,183 - INFO - Lowercase done
# 2025-05-24 22:39:05,210 - INFO - Lowercase done
# 2025-05-24 22:39:05,211 - INFO - lemmarisation done
# 2025-05-24 22:39:05,211 - INFO - Lowercase done
# 2025-05-24 22:39:05,241 - INFO - Lowercase done
# 2025-05-24 22:39:05,241 - INFO - lemmarisation done
# 2025-05-24 22:39:05,242 - INFO - Lowercase done
# 2025-05-24 22:39:05,261 - INFO - Lowercase done
# 2025-05-24 22:39:05,262 - INFO - lemmarisation done
# 2025-05-24 22:39:05,262 - INFO - Lowercase done
# 2025-05-24 22:39:05,279 - INFO - Lowercase done
# 2025-05-24 22:39:05,280 - INFO - lemmarisation done
# 2025-05-24 22:39:05,280 - INFO - Lowercase done
# 2025-05-24 22:39:05,349 - INFO - Lowercase done
# 2025-05-24 22:39:05,350 - INFO - lemmarisation done
# 2025-05-24 22:39:05,351 - INFO - Lowercase done
# 2025-05-24 22:39:05,389 - INFO - Lowercase done
# 2025-05-24 22:39:05,390 - INFO - lemmarisation done
# 2025-05-24 22:39:05,390 - INFO - Lowercase done
# 2025-05-24 22:39:05,399 - INFO - Lowercase done
# 2025-05-24 22:39:05,400 - INFO - lemmarisation done
# 2025-05-24 22:39:05,400 - INFO - Lowercase done
# 2025-05-24 22:39:05,440 - INFO - Lowercase done
# 2025-05-24 22:39:05,440 - INFO - lemmarisation done
# 2025-05-24 22:39:05,441 - INFO - Lowercase done
# 2025-05-24 22:39:05,510 - INFO - Lowercase done
# 2025-05-24 22:39:05,511 - INFO - lemmarisation done
# 2025-05-24 22:39:05,511 - INFO - Lowercase done
# 2025-05-24 22:39:05,524 - INFO - Lowercase done
# 2025-05-24 22:39:05,525 - INFO - lemmarisation done
# 2025-05-24 22:39:05,526 - INFO - Lowercase done
# 2025-05-24 22:39:05,552 - INFO - Lowercase done
# 2025-05-24 22:39:05,553 - INFO - lemmarisation done
# 2025-05-24 22:39:05,553 - INFO - Lowercase done
# 2025-05-24 22:39:05,618 - INFO - Lowercase done
# 2025-05-24 22:39:05,619 - INFO - lemmarisation done
# 2025-05-24 22:39:05,620 - INFO - Lowercase done
# 2025-05-24 22:39:05,663 - INFO - Lowercase done
# 2025-05-24 22:39:05,663 - INFO - lemmarisation done
# 2025-05-24 22:39:05,664 - INFO - Lowercase done
# 2025-05-24 22:39:05,760 - INFO - Lowercase done
# 2025-05-24 22:39:05,761 - INFO - lemmarisation done
# 2025-05-24 22:39:05,762 - INFO - Lowercase done
# 2025-05-24 22:39:05,776 - INFO - Lowercase done
# 2025-05-24 22:39:05,777 - INFO - lemmarisation done
# 2025-05-24 22:39:05,777 - INFO - Lowercase done
# 2025-05-24 22:39:05,785 - INFO - Lowercase done
# 2025-05-24 22:39:05,786 - INFO - lemmarisation done
# 2025-05-24 22:39:05,786 - INFO - Lowercase done
# 2025-05-24 22:39:05,804 - INFO - Lowercase done
# 2025-05-24 22:39:05,805 - INFO - lemmarisation done
# 2025-05-24 22:39:05,806 - INFO - Lowercase done
# 2025-05-24 22:39:05,828 - INFO - Lowercase done
# 2025-05-24 22:39:05,829 - INFO - lemmarisation done
# 2025-05-24 22:39:05,830 - INFO - Lowercase done
# 2025-05-24 22:39:05,856 - INFO - Lowercase done
# 2025-05-24 22:39:05,856 - INFO - lemmarisation done
# 2025-05-24 22:39:05,857 - INFO - Lowercase done
# 2025-05-24 22:39:05,880 - INFO - Lowercase done
# 2025-05-24 22:39:05,881 - INFO - lemmarisation done
# 2025-05-24 22:39:05,882 - INFO - Lowercase done
# 2025-05-24 22:39:05,947 - INFO - Lowercase done
# 2025-05-24 22:39:05,949 - INFO - lemmarisation done
# 2025-05-24 22:39:05,949 - INFO - Lowercase done
# 2025-05-24 22:39:05,965 - INFO - Lowercase done
# 2025-05-24 22:39:05,965 - INFO - lemmarisation done
# 2025-05-24 22:39:05,966 - INFO - Lowercase done
# 2025-05-24 22:39:05,980 - INFO - Lowercase done
# 2025-05-24 22:39:05,981 - INFO - lemmarisation done
# 2025-05-24 22:39:05,981 - INFO - Lowercase done
# 2025-05-24 22:39:06,011 - INFO - Lowercase done
# 2025-05-24 22:39:06,012 - INFO - lemmarisation done
# 2025-05-24 22:39:06,013 - INFO - Lowercase done
# 2025-05-24 22:39:06,055 - INFO - Lowercase done
# 2025-05-24 22:39:06,056 - INFO - lemmarisation done
# 2025-05-24 22:39:06,056 - INFO - Lowercase done
# 2025-05-24 22:39:06,065 - INFO - Lowercase done
# 2025-05-24 22:39:06,065 - INFO - lemmarisation done
# 2025-05-24 22:39:06,066 - INFO - Lowercase done
# 2025-05-24 22:39:06,091 - INFO - Lowercase done
# 2025-05-24 22:39:06,092 - INFO - lemmarisation done
# 2025-05-24 22:39:06,093 - INFO - Lowercase done
# 2025-05-24 22:39:06,106 - INFO - Lowercase done
# 2025-05-24 22:39:06,106 - INFO - lemmarisation done
# 2025-05-24 22:39:06,107 - INFO - Lowercase done
# 2025-05-24 22:39:06,121 - INFO - Lowercase done
# 2025-05-24 22:39:06,122 - INFO - lemmarisation done
# 2025-05-24 22:39:06,122 - INFO - Lowercase done
# 2025-05-24 22:39:06,139 - INFO - Lowercase done
# 2025-05-24 22:39:06,140 - INFO - lemmarisation done
# 2025-05-24 22:39:06,140 - INFO - Lowercase done
# 2025-05-24 22:39:06,160 - INFO - Lowercase done
# 2025-05-24 22:39:06,161 - INFO - lemmarisation done
# 2025-05-24 22:39:06,161 - INFO - Lowercase done
# 2025-05-24 22:39:06,170 - INFO - Lowercase done
# 2025-05-24 22:39:06,170 - INFO - lemmarisation done
# 2025-05-24 22:39:06,171 - INFO - Lowercase done
# 2025-05-24 22:39:06,244 - INFO - Lowercase done
# 2025-05-24 22:39:06,245 - INFO - lemmarisation done
# 2025-05-24 22:39:06,246 - INFO - Lowercase done
# 2025-05-24 22:39:06,252 - INFO - Lowercase done
# 2025-05-24 22:39:06,253 - INFO - lemmarisation done
# 2025-05-24 22:39:06,253 - INFO - Lowercase done
# 2025-05-24 22:39:06,270 - INFO - Lowercase done
# 2025-05-24 22:39:06,271 - INFO - lemmarisation done
# 2025-05-24 22:39:06,272 - INFO - Lowercase done
# 2025-05-24 22:39:06,283 - INFO - Lowercase done
# 2025-05-24 22:39:06,284 - INFO - lemmarisation done
# 2025-05-24 22:39:06,284 - INFO - Lowercase done
# 2025-05-24 22:39:06,304 - INFO - Lowercase done
# 2025-05-24 22:39:06,305 - INFO - lemmarisation done
# 2025-05-24 22:39:06,305 - INFO - Lowercase done
# 2025-05-24 22:39:06,348 - INFO - Lowercase done
# 2025-05-24 22:39:06,349 - INFO - lemmarisation done
# 2025-05-24 22:39:06,350 - INFO - Lowercase done
# 2025-05-24 22:39:06,382 - INFO - Lowercase done
# 2025-05-24 22:39:06,383 - INFO - lemmarisation done
# 2025-05-24 22:39:06,383 - INFO - Lowercase done
# 2025-05-24 22:39:06,399 - INFO - Lowercase done
# 2025-05-24 22:39:06,400 - INFO - lemmarisation done
# 2025-05-24 22:39:06,400 - INFO - Lowercase done
# 2025-05-24 22:39:06,456 - INFO - Lowercase done
# 2025-05-24 22:39:06,457 - INFO - lemmarisation done
# 2025-05-24 22:39:06,458 - INFO - Lowercase done
# 2025-05-24 22:39:06,480 - INFO - Lowercase done
# 2025-05-24 22:39:06,481 - INFO - lemmarisation done
# 2025-05-24 22:39:06,481 - INFO - Lowercase done
# 2025-05-24 22:39:06,496 - INFO - Lowercase done
# 2025-05-24 22:39:06,496 - INFO - lemmarisation done
# 2025-05-24 22:39:06,497 - INFO - Lowercase done
# 2025-05-24 22:39:06,530 - INFO - Lowercase done
# 2025-05-24 22:39:06,531 - INFO - lemmarisation done
# 2025-05-24 22:39:06,531 - INFO - Lowercase done
# 2025-05-24 22:39:06,571 - INFO - Lowercase done
# 2025-05-24 22:39:06,572 - INFO - lemmarisation done
# 2025-05-24 22:39:06,573 - INFO - Lowercase done
# 2025-05-24 22:39:06,610 - INFO - Lowercase done
# 2025-05-24 22:39:06,612 - INFO - lemmarisation done
# 2025-05-24 22:39:06,612 - INFO - Lowercase done
# 2025-05-24 22:39:06,646 - INFO - Lowercase done
# 2025-05-24 22:39:06,647 - INFO - lemmarisation done
# 2025-05-24 22:39:06,647 - INFO - Lowercase done
# 2025-05-24 22:39:06,678 - INFO - Lowercase done
# 2025-05-24 22:39:06,679 - INFO - lemmarisation done
# 2025-05-24 22:39:06,679 - INFO - Lowercase done
# 2025-05-24 22:39:06,717 - INFO - Lowercase done
# 2025-05-24 22:39:06,719 - INFO - lemmarisation done
# 2025-05-24 22:39:06,719 - INFO - Lowercase done
# 2025-05-24 22:39:06,743 - INFO - Lowercase done
# 2025-05-24 22:39:06,744 - INFO - lemmarisation done
# 2025-05-24 22:39:06,744 - INFO - Lowercase done
# 2025-05-24 22:39:06,828 - INFO - Lowercase done
# 2025-05-24 22:39:06,829 - INFO - lemmarisation done
# 2025-05-24 22:39:06,830 - INFO - Lowercase done
# 2025-05-24 22:39:06,849 - INFO - Lowercase done
# 2025-05-24 22:39:06,850 - INFO - lemmarisation done
# 2025-05-24 22:39:06,850 - INFO - Lowercase done
# 2025-05-24 22:39:06,861 - INFO - Lowercase done
# 2025-05-24 22:39:06,862 - INFO - lemmarisation done
# 2025-05-24 22:39:06,862 - INFO - Lowercase done
# 2025-05-24 22:39:06,870 - INFO - Lowercase done
# 2025-05-24 22:39:06,871 - INFO - lemmarisation done
# 2025-05-24 22:39:06,871 - INFO - Lowercase done
# 2025-05-24 22:39:06,889 - INFO - Lowercase done
# 2025-05-24 22:39:06,890 - INFO - lemmarisation done
# 2025-05-24 22:39:06,890 - INFO - Lowercase done
# 2025-05-24 22:39:06,901 - INFO - Lowercase done
# 2025-05-24 22:39:06,901 - INFO - lemmarisation done
# 2025-05-24 22:39:06,902 - INFO - Lowercase done
# 2025-05-24 22:39:06,922 - INFO - Lowercase done
# 2025-05-24 22:39:06,923 - INFO - lemmarisation done
# 2025-05-24 22:39:06,923 - INFO - Lowercase done
# 2025-05-24 22:39:06,940 - INFO - Lowercase done
# 2025-05-24 22:39:06,941 - INFO - lemmarisation done
# 2025-05-24 22:39:06,942 - INFO - Lowercase done
# 2025-05-24 22:39:06,951 - INFO - Lowercase done
# 2025-05-24 22:39:06,952 - INFO - lemmarisation done
# 2025-05-24 22:39:06,952 - INFO - Lowercase done
# 2025-05-24 22:39:06,971 - INFO - Lowercase done
# 2025-05-24 22:39:06,972 - INFO - lemmarisation done
# 2025-05-24 22:39:06,972 - INFO - Lowercase done
# 2025-05-24 22:39:07,008 - INFO - Lowercase done
# 2025-05-24 22:39:07,009 - INFO - lemmarisation done
# 2025-05-24 22:39:07,010 - INFO - Lowercase done
# 2025-05-24 22:39:07,034 - INFO - Lowercase done
# 2025-05-24 22:39:07,035 - INFO - lemmarisation done
# 2025-05-24 22:39:07,035 - INFO - Lowercase done
# 2025-05-24 22:39:07,051 - INFO - Lowercase done
# 2025-05-24 22:39:07,052 - INFO - lemmarisation done
# 2025-05-24 22:39:07,053 - INFO - Lowercase done
# 2025-05-24 22:39:07,070 - INFO - Lowercase done
# 2025-05-24 22:39:07,071 - INFO - lemmarisation done
# 2025-05-24 22:39:07,071 - INFO - Lowercase done
# 2025-05-24 22:39:07,089 - INFO - Lowercase done
# 2025-05-24 22:39:07,090 - INFO - lemmarisation done
# 2025-05-24 22:39:07,091 - INFO - Lowercase done
# 2025-05-24 22:39:07,111 - INFO - Lowercase done
# 2025-05-24 22:39:07,112 - INFO - lemmarisation done
# 2025-05-24 22:39:07,112 - INFO - Lowercase done
# 2025-05-24 22:39:07,131 - INFO - Lowercase done
# 2025-05-24 22:39:07,132 - INFO - lemmarisation done
# 2025-05-24 22:39:07,132 - INFO - Lowercase done
# 2025-05-24 22:39:07,139 - INFO - Lowercase done
# 2025-05-24 22:39:07,140 - INFO - lemmarisation done
# 2025-05-24 22:39:07,140 - INFO - Lowercase done
# 2025-05-24 22:39:07,167 - INFO - Lowercase done
# 2025-05-24 22:39:07,168 - INFO - lemmarisation done
# 2025-05-24 22:39:07,168 - INFO - Lowercase done
# 2025-05-24 22:39:07,186 - INFO - Lowercase done
# 2025-05-24 22:39:07,187 - INFO - lemmarisation done
# 2025-05-24 22:39:07,187 - INFO - Lowercase done
# 2025-05-24 22:39:07,208 - INFO - Lowercase done
# 2025-05-24 22:39:07,209 - INFO - lemmarisation done
# 2025-05-24 22:39:07,209 - INFO - Lowercase done
# 2025-05-24 22:39:07,226 - INFO - Lowercase done
# 2025-05-24 22:39:07,227 - INFO - lemmarisation done
# 2025-05-24 22:39:07,227 - INFO - Lowercase done
# 2025-05-24 22:39:07,244 - INFO - Lowercase done
# 2025-05-24 22:39:07,245 - INFO - lemmarisation done
# 2025-05-24 22:39:07,246 - INFO - Lowercase done
# 2025-05-24 22:39:07,275 - INFO - Lowercase done
# 2025-05-24 22:39:07,276 - INFO - lemmarisation done
# 2025-05-24 22:39:07,276 - INFO - Lowercase done
# 2025-05-24 22:39:07,321 - INFO - Lowercase done
# 2025-05-24 22:39:07,323 - INFO - lemmarisation done
# 2025-05-24 22:39:07,323 - INFO - Lowercase done
# 2025-05-24 22:39:07,367 - INFO - Lowercase done
# 2025-05-24 22:39:07,368 - INFO - lemmarisation done
# 2025-05-24 22:39:07,369 - INFO - Lowercase done
# 2025-05-24 22:39:07,424 - INFO - Lowercase done
# 2025-05-24 22:39:07,426 - INFO - lemmarisation done
# 2025-05-24 22:39:07,426 - INFO - Lowercase done
# 2025-05-24 22:39:07,476 - INFO - Lowercase done
# 2025-05-24 22:39:07,477 - INFO - lemmarisation done
# 2025-05-24 22:39:07,477 - INFO - Lowercase done
# 2025-05-24 22:39:07,495 - INFO - Lowercase done
# 2025-05-24 22:39:07,496 - INFO - lemmarisation done
# 2025-05-24 22:39:07,497 - INFO - Lowercase done
# 2025-05-24 22:39:07,553 - INFO - Lowercase done
# 2025-05-24 22:39:07,554 - INFO - lemmarisation done
# 2025-05-24 22:39:07,555 - INFO - Lowercase done
# 2025-05-24 22:39:07,618 - INFO - Lowercase done
# 2025-05-24 22:39:07,619 - INFO - lemmarisation done
# 2025-05-24 22:39:07,619 - INFO - Lowercase done
# 2025-05-24 22:39:07,659 - INFO - Lowercase done
# 2025-05-24 22:39:07,660 - INFO - lemmarisation done
# 2025-05-24 22:39:07,660 - INFO - Lowercase done
# 2025-05-24 22:39:07,724 - INFO - Lowercase done
# 2025-05-24 22:39:07,725 - INFO - lemmarisation done
# 2025-05-24 22:39:07,726 - INFO - Lowercase done
# 2025-05-24 22:39:07,746 - INFO - Lowercase done
# 2025-05-24 22:39:07,747 - INFO - lemmarisation done
# 2025-05-24 22:39:07,747 - INFO - Lowercase done
# 2025-05-24 22:39:07,782 - INFO - Lowercase done
# 2025-05-24 22:39:07,783 - INFO - lemmarisation done
# 2025-05-24 22:39:07,784 - INFO - Lowercase done
# 2025-05-24 22:39:07,901 - INFO - Lowercase done
# 2025-05-24 22:39:07,902 - INFO - lemmarisation done
# 2025-05-24 22:39:07,902 - INFO - Lowercase done
# 2025-05-24 22:39:07,918 - INFO - Lowercase done
# 2025-05-24 22:39:07,919 - INFO - lemmarisation done
# 2025-05-24 22:39:07,919 - INFO - Lowercase done
# 2025-05-24 22:39:07,937 - INFO - Lowercase done
# 2025-05-24 22:39:07,938 - INFO - lemmarisation done
# 2025-05-24 22:39:07,939 - INFO - Lowercase done
# 2025-05-24 22:39:07,962 - INFO - Lowercase done
# 2025-05-24 22:39:07,963 - INFO - lemmarisation done
# 2025-05-24 22:39:07,963 - INFO - Lowercase done
# 2025-05-24 22:39:08,034 - INFO - Lowercase done
# 2025-05-24 22:39:08,035 - INFO - lemmarisation done
# 2025-05-24 22:39:08,036 - INFO - Lowercase done
# 2025-05-24 22:39:08,056 - INFO - Lowercase done
# 2025-05-24 22:39:08,057 - INFO - lemmarisation done
# 2025-05-24 22:39:08,057 - INFO - Lowercase done
# 2025-05-24 22:39:08,073 - INFO - Lowercase done
# 2025-05-24 22:39:08,074 - INFO - lemmarisation done
# 2025-05-24 22:39:08,074 - INFO - Lowercase done
# 2025-05-24 22:39:08,105 - INFO - Lowercase done
# 2025-05-24 22:39:08,106 - INFO - lemmarisation done
# 2025-05-24 22:39:08,106 - INFO - Lowercase done
# 2025-05-24 22:39:08,128 - INFO - Lowercase done
# 2025-05-24 22:39:08,128 - INFO - lemmarisation done
# 2025-05-24 22:39:08,129 - INFO - Lowercase done
# 2025-05-24 22:39:08,172 - INFO - Lowercase done
# 2025-05-24 22:39:08,173 - INFO - lemmarisation done
# 2025-05-24 22:39:08,173 - INFO - Lowercase done
# 2025-05-24 22:39:08,223 - INFO - Lowercase done
# 2025-05-24 22:39:08,224 - INFO - lemmarisation done
# 2025-05-24 22:39:08,224 - INFO - Lowercase done
# 2025-05-24 22:39:08,248 - INFO - Lowercase done
# 2025-05-24 22:39:08,249 - INFO - lemmarisation done
# 2025-05-24 22:39:08,249 - INFO - Lowercase done
# 2025-05-24 22:39:08,270 - INFO - Lowercase done
# 2025-05-24 22:39:08,272 - INFO - lemmarisation done
# 2025-05-24 22:39:08,273 - INFO - Lowercase done
# 2025-05-24 22:39:08,360 - INFO - Lowercase done
# 2025-05-24 22:39:08,361 - INFO - lemmarisation done
# 2025-05-24 22:39:08,362 - INFO - Lowercase done
# 2025-05-24 22:39:08,406 - INFO - Lowercase done
# 2025-05-24 22:39:08,407 - INFO - lemmarisation done
# 2025-05-24 22:39:08,407 - INFO - Lowercase done
# 2025-05-24 22:39:08,431 - INFO - Lowercase done
# 2025-05-24 22:39:08,432 - INFO - lemmarisation done
# 2025-05-24 22:39:08,432 - INFO - Lowercase done
# 2025-05-24 22:39:08,441 - INFO - Lowercase done
# 2025-05-24 22:39:08,442 - INFO - lemmarisation done
# 2025-05-24 22:39:08,442 - INFO - Lowercase done
# 2025-05-24 22:39:08,477 - INFO - Lowercase done
# 2025-05-24 22:39:08,478 - INFO - lemmarisation done
# 2025-05-24 22:39:08,478 - INFO - Lowercase done
# 2025-05-24 22:39:08,492 - INFO - Lowercase done
# 2025-05-24 22:39:08,493 - INFO - lemmarisation done
# 2025-05-24 22:39:08,493 - INFO - Lowercase done
# 2025-05-24 22:39:08,515 - INFO - Lowercase done
# 2025-05-24 22:39:08,516 - INFO - lemmarisation done
# 2025-05-24 22:39:08,516 - INFO - Lowercase done
# 2025-05-24 22:39:08,539 - INFO - Lowercase done
# 2025-05-24 22:39:08,540 - INFO - lemmarisation done
# 2025-05-24 22:39:08,540 - INFO - Lowercase done
# 2025-05-24 22:39:08,566 - INFO - Lowercase done
# 2025-05-24 22:39:08,567 - INFO - lemmarisation done
# 2025-05-24 22:39:08,567 - INFO - Lowercase done
# 2025-05-24 22:39:08,585 - INFO - Lowercase done
# 2025-05-24 22:39:08,586 - INFO - lemmarisation done
# 2025-05-24 22:39:08,586 - INFO - Lowercase done
# 2025-05-24 22:39:08,627 - INFO - Lowercase done
# 2025-05-24 22:39:08,628 - INFO - lemmarisation done
# 2025-05-24 22:39:08,629 - INFO - Lowercase done
# 2025-05-24 22:39:08,642 - INFO - Lowercase done
# 2025-05-24 22:39:08,643 - INFO - lemmarisation done
# 2025-05-24 22:39:08,644 - INFO - Lowercase done
# 2025-05-24 22:39:08,686 - INFO - Lowercase done
# 2025-05-24 22:39:08,687 - INFO - lemmarisation done
# 2025-05-24 22:39:08,688 - INFO - Lowercase done
# 2025-05-24 22:39:08,705 - INFO - Lowercase done
# 2025-05-24 22:39:08,705 - INFO - lemmarisation done
# 2025-05-24 22:39:08,706 - INFO - Lowercase done
# 2025-05-24 22:39:08,728 - INFO - Lowercase done
# 2025-05-24 22:39:08,728 - INFO - lemmarisation done
# 2025-05-24 22:39:08,729 - INFO - Lowercase done
# 2025-05-24 22:39:08,743 - INFO - Lowercase done
# 2025-05-24 22:39:08,744 - INFO - lemmarisation done
# 2025-05-24 22:39:08,744 - INFO - Lowercase done
# 2025-05-24 22:39:08,764 - INFO - Lowercase done
# 2025-05-24 22:39:08,765 - INFO - lemmarisation done
# 2025-05-24 22:39:08,765 - INFO - Lowercase done
# 2025-05-24 22:39:08,790 - INFO - Lowercase done
# 2025-05-24 22:39:08,791 - INFO - lemmarisation done
# 2025-05-24 22:39:08,791 - INFO - Lowercase done
# 2025-05-24 22:39:08,808 - INFO - Lowercase done
# 2025-05-24 22:39:08,808 - INFO - lemmarisation done
# 2025-05-24 22:39:08,809 - INFO - Lowercase done
# 2025-05-24 22:39:08,866 - INFO - Lowercase done
# 2025-05-24 22:39:08,867 - INFO - lemmarisation done
# 2025-05-24 22:39:08,868 - INFO - Lowercase done
# 2025-05-24 22:39:08,886 - INFO - Lowercase done
# 2025-05-24 22:39:08,886 - INFO - lemmarisation done
# 2025-05-24 22:39:08,887 - INFO - Lowercase done
# 2025-05-24 22:39:08,963 - INFO - Lowercase done
# 2025-05-24 22:39:08,964 - INFO - lemmarisation done
# 2025-05-24 22:39:08,964 - INFO - Lowercase done
# 2025-05-24 22:39:09,000 - INFO - Lowercase done
# 2025-05-24 22:39:09,001 - INFO - lemmarisation done
# 2025-05-24 22:39:09,002 - INFO - Lowercase done
# 2025-05-24 22:39:09,018 - INFO - Lowercase done
# 2025-05-24 22:39:09,019 - INFO - lemmarisation done
# 2025-05-24 22:39:09,019 - INFO - Lowercase done
# 2025-05-24 22:39:09,041 - INFO - Lowercase done
# 2025-05-24 22:39:09,041 - INFO - lemmarisation done
# 2025-05-24 22:39:09,042 - INFO - Lowercase done
# 2025-05-24 22:39:09,062 - INFO - Lowercase done
# 2025-05-24 22:39:09,063 - INFO - lemmarisation done
# 2025-05-24 22:39:09,064 - INFO - Lowercase done
# 2025-05-24 22:39:09,080 - INFO - Lowercase done
# 2025-05-24 22:39:09,080 - INFO - lemmarisation done
# 2025-05-24 22:39:09,081 - INFO - Lowercase done
# 2025-05-24 22:39:09,114 - INFO - Lowercase done
# 2025-05-24 22:39:09,115 - INFO - lemmarisation done
# 2025-05-24 22:39:09,116 - INFO - Lowercase done
# 2025-05-24 22:39:09,145 - INFO - Lowercase done
# 2025-05-24 22:39:09,146 - INFO - lemmarisation done
# 2025-05-24 22:39:09,146 - INFO - Lowercase done
# 2025-05-24 22:39:09,158 - INFO - Lowercase done
# 2025-05-24 22:39:09,159 - INFO - lemmarisation done
# 2025-05-24 22:39:09,159 - INFO - Lowercase done
# 2025-05-24 22:39:09,197 - INFO - Lowercase done
# 2025-05-24 22:39:09,198 - INFO - lemmarisation done
# 2025-05-24 22:39:09,199 - INFO - Lowercase done
# 2025-05-24 22:39:09,216 - INFO - Lowercase done
# 2025-05-24 22:39:09,217 - INFO - lemmarisation done
# 2025-05-24 22:39:09,217 - INFO - Lowercase done
# 2025-05-24 22:39:09,230 - INFO - Lowercase done
# 2025-05-24 22:39:09,231 - INFO - lemmarisation done
# 2025-05-24 22:39:09,231 - INFO - Lowercase done
# 2025-05-24 22:39:09,247 - INFO - Lowercase done
# 2025-05-24 22:39:09,248 - INFO - lemmarisation done
# 2025-05-24 22:39:09,249 - INFO - Lowercase done
# 2025-05-24 22:39:09,378 - INFO - Lowercase done
# 2025-05-24 22:39:09,379 - INFO - lemmarisation done
# 2025-05-24 22:39:09,380 - INFO - Lowercase done
# 2025-05-24 22:39:09,393 - INFO - Lowercase done
# 2025-05-24 22:39:09,394 - INFO - lemmarisation done
# 2025-05-24 22:39:09,395 - INFO - Lowercase done
# 2025-05-24 22:39:09,410 - INFO - Lowercase done
# 2025-05-24 22:39:09,411 - INFO - lemmarisation done
# 2025-05-24 22:39:09,411 - INFO - Lowercase done
# 2025-05-24 22:39:09,423 - INFO - Lowercase done
# 2025-05-24 22:39:09,423 - INFO - lemmarisation done
# 2025-05-24 22:39:09,424 - INFO - Lowercase done
# 2025-05-24 22:39:09,479 - INFO - Lowercase done
# 2025-05-24 22:39:09,480 - INFO - lemmarisation done
# 2025-05-24 22:39:09,480 - INFO - Lowercase done
# 2025-05-24 22:39:09,517 - INFO - Lowercase done
# 2025-05-24 22:39:09,517 - INFO - lemmarisation done
# 2025-05-24 22:39:09,518 - INFO - Lowercase done
# 2025-05-24 22:39:09,538 - INFO - Lowercase done
# 2025-05-24 22:39:09,539 - INFO - lemmarisation done
# 2025-05-24 22:39:09,539 - INFO - Lowercase done
# 2025-05-24 22:39:09,550 - INFO - Lowercase done
# 2025-05-24 22:39:09,551 - INFO - lemmarisation done
# 2025-05-24 22:39:09,552 - INFO - Lowercase done
# 2025-05-24 22:39:09,586 - INFO - Lowercase done
# 2025-05-24 22:39:09,587 - INFO - lemmarisation done
# 2025-05-24 22:39:09,588 - INFO - Lowercase done
# 2025-05-24 22:39:09,633 - INFO - Lowercase done
# 2025-05-24 22:39:09,635 - INFO - lemmarisation done
# 2025-05-24 22:39:09,635 - INFO - Lowercase done
# 2025-05-24 22:39:09,756 - INFO - Lowercase done
# 2025-05-24 22:39:09,758 - INFO - lemmarisation done
# 2025-05-24 22:39:09,758 - INFO - Lowercase done
# 2025-05-24 22:39:09,768 - INFO - Lowercase done
# 2025-05-24 22:39:09,768 - INFO - lemmarisation done
# 2025-05-24 22:39:09,769 - INFO - Lowercase done
# 2025-05-24 22:39:09,860 - INFO - Lowercase done
# 2025-05-24 22:39:09,861 - INFO - lemmarisation done
# 2025-05-24 22:39:09,862 - INFO - Lowercase done
# 2025-05-24 22:39:09,879 - INFO - Lowercase done
# 2025-05-24 22:39:09,880 - INFO - lemmarisation done
# 2025-05-24 22:39:09,880 - INFO - Lowercase done
# ...
# 2025-05-24 23:11:36,128 - INFO - lemmarisation done
# 2025-05-24 23:11:36,130 - INFO - Lowercase done
# 2025-05-24 23:11:36,148 - INFO - Lowercase done
# 2025-05-24 23:11:36,150 - INFO - lemmarisation done
# 2025-05-24 23:11:36,153 - INFO - Lowercase done
# 2025-05-24 23:11:36,175 - INFO - Lowercase done
# 2025-05-24 23:11:36,178 - INFO - lemmarisation done
# 2025-05-24 23:11:36,181 - INFO - Lowercase done
# 2025-05-24 23:11:36,214 - INFO - Lowercase done
# 2025-05-24 23:11:36,217 - INFO - lemmarisation done
# 2025-05-24 23:11:36,220 - INFO - Lowercase done
# 2025-05-24 23:11:36,242 - INFO - Lowercase done
# 2025-05-24 23:11:36,245 - INFO - lemmarisation done
# 2025-05-24 23:11:36,248 - INFO - Lowercase done
# 2025-05-24 23:11:36,259 - INFO - Lowercase done
# 2025-05-24 23:11:36,262 - INFO - lemmarisation done
# 2025-05-24 23:11:36,264 - INFO - Lowercase done
# 2025-05-24 23:11:36,295 - INFO - Lowercase done
# 2025-05-24 23:11:36,298 - INFO - lemmarisation done
# 2025-05-24 23:11:36,301 - INFO - Lowercase done
# 2025-05-24 23:11:36,398 - INFO - Lowercase done
# 2025-05-24 23:11:36,401 - INFO - lemmarisation done
# 2025-05-24 23:11:36,403 - INFO - Lowercase done
# 2025-05-24 23:11:36,414 - INFO - Lowercase done
# 2025-05-24 23:11:36,416 - INFO - lemmarisation done
# 2025-05-24 23:11:36,419 - INFO - Lowercase done
# 2025-05-24 23:11:36,431 - INFO - Lowercase done
# 2025-05-24 23:11:36,433 - INFO - lemmarisation done
# 2025-05-24 23:11:36,435 - INFO - Lowercase done
# 2025-05-24 23:11:36,509 - INFO - Lowercase done
# 2025-05-24 23:11:36,512 - INFO - lemmarisation done
# 2025-05-24 23:11:36,514 - INFO - Lowercase done
# 2025-05-24 23:11:36,535 - INFO - Lowercase done
# 2025-05-24 23:11:36,538 - INFO - lemmarisation done
# 2025-05-24 23:11:36,540 - INFO - Lowercase done
# 2025-05-24 23:11:36,559 - INFO - Lowercase done
# 2025-05-24 23:11:36,561 - INFO - lemmarisation done
# 2025-05-24 23:11:36,564 - INFO - Lowercase done
# 2025-05-24 23:11:36,574 - INFO - Lowercase done
# 2025-05-24 23:11:36,576 - INFO - lemmarisation done
# 2025-05-24 23:11:36,578 - INFO - Lowercase done
# 2025-05-24 23:11:36,676 - INFO - Lowercase done
# 2025-05-24 23:11:36,679 - INFO - lemmarisation done
# 2025-05-24 23:11:36,681 - INFO - Lowercase done
# 2025-05-24 23:11:36,706 - INFO - Lowercase done
# 2025-05-24 23:11:36,708 - INFO - lemmarisation done
# 2025-05-24 23:11:36,710 - INFO - Lowercase done
# 2025-05-24 23:11:36,744 - INFO - Lowercase done
# 2025-05-24 23:11:36,747 - INFO - lemmarisation done
# 2025-05-24 23:11:36,751 - INFO - Lowercase done
# 2025-05-24 23:11:36,789 - INFO - Lowercase done
# 2025-05-24 23:11:36,792 - INFO - lemmarisation done
# 2025-05-24 23:11:36,795 - INFO - Lowercase done
# 2025-05-24 23:11:36,810 - INFO - Lowercase done
# 2025-05-24 23:11:36,812 - INFO - lemmarisation done
# 2025-05-24 23:11:36,815 - INFO - Lowercase done
# 2025-05-24 23:11:36,826 - INFO - Lowercase done
# 2025-05-24 23:11:36,830 - INFO - lemmarisation done
# 2025-05-24 23:11:36,832 - INFO - Lowercase done
# 2025-05-24 23:11:36,866 - INFO - Lowercase done
# 2025-05-24 23:11:36,869 - INFO - lemmarisation done
# 2025-05-24 23:11:36,871 - INFO - Lowercase done
# 2025-05-24 23:11:36,946 - INFO - Lowercase done
# 2025-05-24 23:11:36,949 - INFO - lemmarisation done
# 2025-05-24 23:11:36,952 - INFO - Lowercase done
# 2025-05-24 23:11:36,979 - INFO - Lowercase done
# 2025-05-24 23:11:36,982 - INFO - lemmarisation done
# 2025-05-24 23:11:36,984 - INFO - Lowercase done
# 2025-05-24 23:11:36,995 - INFO - Lowercase done
# 2025-05-24 23:11:36,998 - INFO - lemmarisation done
# 2025-05-24 23:11:37,000 - INFO - Lowercase done
# 2025-05-24 23:11:37,068 - INFO - Lowercase done
# 2025-05-24 23:11:37,071 - INFO - lemmarisation done
# 2025-05-24 23:11:37,073 - INFO - Lowercase done
# 2025-05-24 23:11:37,094 - INFO - Lowercase done
# 2025-05-24 23:11:37,097 - INFO - lemmarisation done
# 2025-05-24 23:11:37,099 - INFO - Lowercase done
# 2025-05-24 23:11:37,122 - INFO - Lowercase done
# 2025-05-24 23:11:37,124 - INFO - lemmarisation done
# 2025-05-24 23:11:37,126 - INFO - Lowercase done
# 2025-05-24 23:11:37,150 - INFO - Lowercase done
# 2025-05-24 23:11:37,153 - INFO - lemmarisation done
# 2025-05-24 23:11:37,156 - INFO - Lowercase done
# 2025-05-24 23:11:37,260 - INFO - Lowercase done
# 2025-05-24 23:11:37,263 - INFO - lemmarisation done
# 2025-05-24 23:11:37,265 - INFO - Lowercase done
# 2025-05-24 23:11:37,292 - INFO - Lowercase done
# 2025-05-24 23:11:37,295 - INFO - lemmarisation done
# 2025-05-24 23:11:37,297 - INFO - Lowercase done
# 2025-05-24 23:11:37,343 - INFO - Lowercase done
# 2025-05-24 23:11:37,346 - INFO - lemmarisation done
# 2025-05-24 23:11:37,348 - INFO - Lowercase done
# 2025-05-24 23:11:37,379 - INFO - Lowercase done
# 2025-05-24 23:11:37,382 - INFO - lemmarisation done
# 2025-05-24 23:11:37,385 - INFO - Lowercase done
# 2025-05-24 23:11:37,394 - INFO - Lowercase done
# 2025-05-24 23:11:37,396 - INFO - lemmarisation done
# 2025-05-24 23:11:37,398 - INFO - Lowercase done
# 2025-05-24 23:11:37,442 - INFO - Lowercase done
# 2025-05-24 23:11:37,445 - INFO - lemmarisation done
# 2025-05-24 23:11:37,448 - INFO - Lowercase done
# 2025-05-24 23:11:37,472 - INFO - Lowercase done
# 2025-05-24 23:11:37,475 - INFO - lemmarisation done
# 2025-05-24 23:11:37,478 - INFO - Lowercase done
# 2025-05-24 23:11:37,499 - INFO - Lowercase done
# 2025-05-24 23:11:37,502 - INFO - lemmarisation done
# 2025-05-24 23:11:37,504 - INFO - Lowercase done
# 2025-05-24 23:11:37,530 - INFO - Lowercase done
# 2025-05-24 23:11:37,533 - INFO - lemmarisation done
# 2025-05-24 23:11:37,535 - INFO - Lowercase done
# 2025-05-24 23:11:37,558 - INFO - Lowercase done
# 2025-05-24 23:11:37,561 - INFO - lemmarisation done
# 2025-05-24 23:11:37,565 - INFO - Lowercase done
# 2025-05-24 23:11:37,583 - INFO - Lowercase done
# 2025-05-24 23:11:37,586 - INFO - lemmarisation done
# 2025-05-24 23:11:37,589 - INFO - Lowercase done
# 2025-05-24 23:11:37,610 - INFO - Lowercase done
# 2025-05-24 23:11:37,612 - INFO - lemmarisation done
# 2025-05-24 23:11:37,615 - INFO - Lowercase done
# 2025-05-24 23:11:37,638 - INFO - Lowercase done
# 2025-05-24 23:11:37,640 - INFO - lemmarisation done
# 2025-05-24 23:11:37,643 - INFO - Lowercase done
# 2025-05-24 23:11:37,696 - INFO - Lowercase done
# 2025-05-24 23:11:37,698 - INFO - lemmarisation done
# 2025-05-24 23:11:37,700 - INFO - Lowercase done
# 2025-05-24 23:11:37,745 - INFO - Lowercase done
# 2025-05-24 23:11:37,748 - INFO - lemmarisation done
# 2025-05-24 23:11:37,751 - INFO - Lowercase done
# 2025-05-24 23:11:37,764 - INFO - Lowercase done
# 2025-05-24 23:11:37,767 - INFO - lemmarisation done
# 2025-05-24 23:11:37,770 - INFO - Lowercase done
# 2025-05-24 23:11:37,793 - INFO - Lowercase done
# 2025-05-24 23:11:37,797 - INFO - lemmarisation done
# 2025-05-24 23:11:37,799 - INFO - Lowercase done
# 2025-05-24 23:11:37,807 - INFO - Lowercase done
# 2025-05-24 23:11:37,809 - INFO - lemmarisation done
# 2025-05-24 23:11:37,812 - INFO - Lowercase done
# 2025-05-24 23:11:37,900 - INFO - Lowercase done
# 2025-05-24 23:11:37,903 - INFO - lemmarisation done
# 2025-05-24 23:11:37,905 - INFO - Lowercase done
# 2025-05-24 23:11:37,927 - INFO - Lowercase done
# 2025-05-24 23:11:37,930 - INFO - lemmarisation done
# 2025-05-24 23:11:37,933 - INFO - Lowercase done
# 2025-05-24 23:11:37,949 - INFO - Lowercase done
# 2025-05-24 23:11:37,952 - INFO - lemmarisation done
# 2025-05-24 23:11:37,955 - INFO - Lowercase done
# 2025-05-24 23:11:38,035 - INFO - Lowercase done
# 2025-05-24 23:11:38,038 - INFO - lemmarisation done
# 2025-05-24 23:11:38,040 - INFO - Lowercase done
# 2025-05-24 23:11:38,060 - INFO - Lowercase done
# 2025-05-24 23:11:38,062 - INFO - lemmarisation done
# 2025-05-24 23:11:38,064 - INFO - Lowercase done
# 2025-05-24 23:11:38,200 - INFO - Lowercase done
# 2025-05-24 23:11:38,203 - INFO - lemmarisation done
# 2025-05-24 23:11:38,205 - INFO - Lowercase done
# 2025-05-24 23:11:38,235 - INFO - Lowercase done
# 2025-05-24 23:11:38,238 - INFO - lemmarisation done
# 2025-05-24 23:11:38,240 - INFO - Lowercase done
# 2025-05-24 23:11:38,268 - INFO - Lowercase done
# 2025-05-24 23:11:38,271 - INFO - lemmarisation done
# 2025-05-24 23:11:38,273 - INFO - Lowercase done
# 2025-05-24 23:11:38,322 - INFO - Lowercase done
# 2025-05-24 23:11:38,325 - INFO - lemmarisation done
# 2025-05-24 23:11:38,327 - INFO - Lowercase done
# 2025-05-24 23:11:38,348 - INFO - Lowercase done
# 2025-05-24 23:11:38,350 - INFO - lemmarisation done
# 2025-05-24 23:11:38,352 - INFO - Lowercase done
# 2025-05-24 23:11:38,410 - INFO - Lowercase done
# 2025-05-24 23:11:38,413 - INFO - lemmarisation done
# 2025-05-24 23:11:38,415 - INFO - Lowercase done
# 2025-05-24 23:11:38,485 - INFO - Lowercase done
# 2025-05-24 23:11:38,488 - INFO - lemmarisation done
# 2025-05-24 23:11:38,490 - INFO - Lowercase done
# 2025-05-24 23:11:38,504 - INFO - Lowercase done
# 2025-05-24 23:11:38,507 - INFO - lemmarisation done
# 2025-05-24 23:11:38,509 - INFO - Lowercase done
# 2025-05-24 23:11:38,538 - INFO - Lowercase done
# 2025-05-24 23:11:38,541 - INFO - lemmarisation done
# 2025-05-24 23:11:38,544 - INFO - Lowercase done
# 2025-05-24 23:11:38,574 - INFO - Lowercase done
# 2025-05-24 23:11:38,577 - INFO - lemmarisation done
# 2025-05-24 23:11:38,579 - INFO - Lowercase done
# 2025-05-24 23:11:38,614 - INFO - Lowercase done
# 2025-05-24 23:11:38,617 - INFO - lemmarisation done
# 2025-05-24 23:11:38,620 - INFO - Lowercase done
# 2025-05-24 23:11:38,707 - INFO - Lowercase done
# 2025-05-24 23:11:38,710 - INFO - lemmarisation done
# 2025-05-24 23:11:38,712 - INFO - Lowercase done
# 2025-05-24 23:11:38,778 - INFO - Lowercase done
# 2025-05-24 23:11:38,781 - INFO - lemmarisation done
# 2025-05-24 23:11:38,783 - INFO - Lowercase done
# 2025-05-24 23:11:38,813 - INFO - Lowercase done
# 2025-05-24 23:11:38,816 - INFO - lemmarisation done
# 2025-05-24 23:11:38,818 - INFO - Lowercase done
# 2025-05-24 23:11:38,853 - INFO - Lowercase done
# 2025-05-24 23:11:38,855 - INFO - lemmarisation done
# 2025-05-24 23:11:38,858 - INFO - Lowercase done
# 2025-05-24 23:11:38,869 - INFO - Lowercase done
# 2025-05-24 23:11:38,871 - INFO - lemmarisation done
# 2025-05-24 23:11:38,875 - INFO - Lowercase done
# 2025-05-24 23:11:38,911 - INFO - Lowercase done
# 2025-05-24 23:11:38,914 - INFO - lemmarisation done
# 2025-05-24 23:11:38,916 - INFO - Lowercase done
# 2025-05-24 23:11:38,945 - INFO - Lowercase done
# 2025-05-24 23:11:38,948 - INFO - lemmarisation done
# 2025-05-24 23:11:38,951 - INFO - Lowercase done
# 2025-05-24 23:11:38,969 - INFO - Lowercase done
# 2025-05-24 23:11:38,972 - INFO - lemmarisation done
# 2025-05-24 23:11:38,974 - INFO - Lowercase done
# 2025-05-24 23:11:38,996 - INFO - Lowercase done
# 2025-05-24 23:11:38,999 - INFO - lemmarisation done
# 2025-05-24 23:11:39,002 - INFO - Lowercase done
# 2025-05-24 23:11:39,014 - INFO - Lowercase done
# 2025-05-24 23:11:39,018 - INFO - lemmarisation done
# 2025-05-24 23:11:39,021 - INFO - Lowercase done
# 2025-05-24 23:11:39,033 - INFO - Lowercase done
# 2025-05-24 23:11:39,036 - INFO - lemmarisation done
# 2025-05-24 23:11:39,038 - INFO - Lowercase done
# 2025-05-24 23:11:39,064 - INFO - Lowercase done
# 2025-05-24 23:11:39,067 - INFO - lemmarisation done
# 2025-05-24 23:11:39,070 - INFO - Lowercase done
# 2025-05-24 23:11:39,092 - INFO - Lowercase done
# 2025-05-24 23:11:39,095 - INFO - lemmarisation done
# 2025-05-24 23:11:39,097 - INFO - Lowercase done
# 2025-05-24 23:11:39,145 - INFO - Lowercase done
# 2025-05-24 23:11:39,148 - INFO - lemmarisation done
# 2025-05-24 23:11:39,150 - INFO - Lowercase done
# 2025-05-24 23:11:39,176 - INFO - Lowercase done
# 2025-05-24 23:11:39,180 - INFO - lemmarisation done
# 2025-05-24 23:11:39,182 - INFO - Lowercase done
# 2025-05-24 23:11:39,203 - INFO - Lowercase done
# 2025-05-24 23:11:39,206 - INFO - lemmarisation done
# 2025-05-24 23:11:39,208 - INFO - Lowercase done
# 2025-05-24 23:11:39,243 - INFO - Lowercase done
# 2025-05-24 23:11:39,248 - INFO - lemmarisation done
# 2025-05-24 23:11:39,250 - INFO - Lowercase done
# 2025-05-24 23:11:39,287 - INFO - Lowercase done
# 2025-05-24 23:11:39,290 - INFO - lemmarisation done
# 2025-05-24 23:11:39,292 - INFO - Lowercase done
# 2025-05-24 23:11:39,340 - INFO - Lowercase done
# 2025-05-24 23:11:39,343 - INFO - lemmarisation done
# 2025-05-24 23:11:39,346 - INFO - Lowercase done
# 2025-05-24 23:11:39,385 - INFO - Lowercase done
# 2025-05-24 23:11:39,389 - INFO - lemmarisation done
# 2025-05-24 23:11:39,392 - INFO - Lowercase done
# 2025-05-24 23:11:39,428 - INFO - Lowercase done
# 2025-05-24 23:11:39,431 - INFO - lemmarisation done
# 2025-05-24 23:11:39,434 - INFO - Lowercase done
# 2025-05-24 23:11:39,464 - INFO - Lowercase done
# 2025-05-24 23:11:39,467 - INFO - lemmarisation done
# 2025-05-24 23:11:39,469 - INFO - Lowercase done
# 2025-05-24 23:11:39,583 - INFO - Lowercase done
# 2025-05-24 23:11:39,586 - INFO - lemmarisation done
# 2025-05-24 23:11:39,588 - INFO - Lowercase done
# 2025-05-24 23:11:39,638 - INFO - Lowercase done
# 2025-05-24 23:11:39,640 - INFO - lemmarisation done
# 2025-05-24 23:11:39,642 - INFO - Lowercase done
# 2025-05-24 23:11:39,662 - INFO - Lowercase done
# 2025-05-24 23:11:39,664 - INFO - lemmarisation done
# 2025-05-24 23:11:39,666 - INFO - Lowercase done
# 2025-05-24 23:11:39,726 - INFO - Lowercase done
# 2025-05-24 23:11:39,729 - INFO - lemmarisation done
# 2025-05-24 23:11:39,731 - INFO - Lowercase done
# 2025-05-24 23:11:39,762 - INFO - Lowercase done
# 2025-05-24 23:11:39,765 - INFO - lemmarisation done
# 2025-05-24 23:11:39,766 - INFO - Lowercase done
# 2025-05-24 23:11:39,784 - INFO - Lowercase done
# 2025-05-24 23:11:39,788 - INFO - lemmarisation done
# 2025-05-24 23:11:39,790 - INFO - Lowercase done
# 2025-05-24 23:11:39,811 - INFO - Lowercase done
# 2025-05-24 23:11:39,814 - INFO - lemmarisation done
# 2025-05-24 23:11:39,816 - INFO - Lowercase done
# 2025-05-24 23:11:39,862 - INFO - Lowercase done
# 2025-05-24 23:11:39,866 - INFO - lemmarisation done
# 2025-05-24 23:11:39,869 - INFO - Lowercase done
# 2025-05-24 23:11:39,896 - INFO - Lowercase done
# 2025-05-24 23:11:39,899 - INFO - lemmarisation done
# 2025-05-24 23:11:39,901 - INFO - Lowercase done
# 2025-05-24 23:11:39,922 - INFO - Lowercase done
# 2025-05-24 23:11:39,925 - INFO - lemmarisation done
# 2025-05-24 23:11:39,928 - INFO - Lowercase done
# 2025-05-24 23:11:39,970 - INFO - Lowercase done
# 2025-05-24 23:11:39,973 - INFO - lemmarisation done
# 2025-05-24 23:11:39,976 - INFO - Lowercase done
# 2025-05-24 23:11:40,004 - INFO - Lowercase done
# 2025-05-24 23:11:40,007 - INFO - lemmarisation done
# 2025-05-24 23:11:40,009 - INFO - Lowercase done
# 2025-05-24 23:11:40,080 - INFO - Lowercase done
# 2025-05-24 23:11:40,083 - INFO - lemmarisation done
# 2025-05-24 23:11:40,085 - INFO - Lowercase done
# 2025-05-24 23:11:40,105 - INFO - Lowercase done
# 2025-05-24 23:11:40,107 - INFO - lemmarisation done
# 2025-05-24 23:11:40,109 - INFO - Lowercase done
# 2025-05-24 23:11:40,138 - INFO - Lowercase done
# 2025-05-24 23:11:40,140 - INFO - lemmarisation done
# 2025-05-24 23:11:40,143 - INFO - Lowercase done
# 2025-05-24 23:11:40,161 - INFO - Lowercase done
# 2025-05-24 23:11:40,163 - INFO - lemmarisation done
# 2025-05-24 23:11:40,167 - INFO - Lowercase done
# 2025-05-24 23:11:40,202 - INFO - Lowercase done
# 2025-05-24 23:11:40,205 - INFO - lemmarisation done
# 2025-05-24 23:11:40,208 - INFO - Lowercase done
# 2025-05-24 23:11:40,241 - INFO - Lowercase done
# 2025-05-24 23:11:40,244 - INFO - lemmarisation done
# 2025-05-24 23:11:40,246 - INFO - Lowercase done
# 2025-05-24 23:11:40,266 - INFO - Lowercase done
# 2025-05-24 23:11:40,269 - INFO - lemmarisation done
#                                                   review sentiment
# 0      one reviewer mentioned watching oz episode hoo...  positive
# 1      wonderful little production br br filming tech...  positive
# 2      thought wonderful way spend time hot summer we...  positive
# 3      basically family little boy jake think zombie ...  negative
# 4      petter mattei love time money visually stunnin...  positive
# ...                                                  ...       ...
# 49995  thought movie right good job creative original...  positive
# 49996  bad plot bad dialogue bad acting idiotic direc...  negative
# 49997  catholic taught parochial elementary school nu...  negative
# 49998  going disagree previous comment side maltin on...  negative
# 49999  one expects star trek movie high art fan expec...  negative
#
# [50000 rows x 2 columns]

# %%
cleaned_data = cleaned_data.drop_duplicates()

# %%
cleaned_data.to_pickle('cleaned_data.pkl')

# %%
cleaned_data = pd.read_pickle('cleaned_data.pkl')
cleaned_data
# Out:
#                                                   review sentiment
# 0      one reviewer mentioned watching oz episode hoo...  positive
# 1      wonderful little production br br filming tech...  positive
# 2      thought wonderful way spend time hot summer we...  positive
# 3      basically family little boy jake think zombie ...  negative
# 4      petter mattei love time money visually stunnin...  positive
# ...                                                  ...       ...
# 49995  thought movie right good job creative original...  positive
# 49996  bad plot bad dialogue bad acting idiotic direc...  negative
# 49997  catholic taught parochial elementary school nu...  negative
# 49998  going disagree previous comment side maltin on...  negative
# 49999  one expects star trek movie high art fan expec...  negative
#
# [49576 rows x 2 columns]

# %% [markdown]
# # Exploratary analysis - clean version

# %%
# Get info about the dataset
cleaned_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 49576 entries, 0 to 49999
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   review     49576 non-null  object
#  1   sentiment  49576 non-null  object
# dtypes: object(2)
# memory usage: 1.1+ MB

# %%
# Check for missing values
cleaned_data.isnull().sum()
# Out:
# review       0
# sentiment    0
# dtype: int64

# %%
# Get basic statistics
cleaned_data.describe(include='all')
# Out:
#                                                    review sentiment
# count                                               49576     49576
# unique                                              49576         2
# top     one expects star trek movie high art fan expec...  positive
# freq                                                    1     24880

# %%
# Check sentiment distribution
cleaned_data['sentiment'].value_counts()
# Out:
# sentiment
# positive    24880
# negative    24696
# Name: count, dtype: int64

# %%
# Add a column that counts the number of words in the 'review' column
data_with_word_count = cleaned_data.copy()
data_with_word_count['review_word_count'] = data_with_word_count['review'].str.split().apply(len)
data_with_word_count
# Out:
#                                                   review sentiment  \
# 0      one reviewer mentioned watching oz episode hoo...  positive
# 1      wonderful little production br br filming tech...  positive
# 2      thought wonderful way spend time hot summer we...  positive
# 3      basically family little boy jake think zombie ...  negative
# 4      petter mattei love time money visually stunnin...  positive
# ...                                                  ...       ...
# 49995  thought movie right good job creative original...  positive
# 49996  bad plot bad dialogue bad acting idiotic direc...  negative
# 49997  catholic taught parochial elementary school nu...  negative
# 49998  going disagree previous comment side maltin on...  negative
# 49999  one expects star trek movie high art fan expec...  negative
#
#        review_word_count
# 0                    168
# 1                     92
# 2                     88
# 3                     70
# 4                    133
# ...                  ...
# 49995                 81
# 49996                 61
# 49997                117
# 49998                112
# 49999                 68
#
# [49576 rows x 3 columns]

# %%
plt.figure(figsize=(16,9))
ax = data_with_word_count['review_word_count'].hist(bins=50)
plt.title('Distribution of Review Word Count')
plt.xlabel('Number of Words')
plt.ylabel('Frequency')
plt.xticks(
    ticks=range(
        int(data_with_word_count['review_word_count'].min()),
        int(data_with_word_count['review_word_count'].max())+1,
        50  # Set tick interval to 10, adjust as needed
    )
)
plt.show()

# %%
data_with_word_count['review_word_count'].describe()
# Out:
# count    49576.000000
# mean       122.299964
# std         92.636798
# min          3.000000
# 25%         65.000000
# 50%         90.000000
# 75%        149.000000
# max       1442.000000
# Name: review_word_count, dtype: float64

# %%
# Group by review_word_count, aggregate by count, and order by count descending
review_length_distribution = (
    data_with_word_count.groupby('review_word_count')
    .size()
    .reset_index(name='count')
    .sort_values(by='count', ascending=False)
)
review_length_distribution
# Out:
#      review_word_count  count
# 61                  64    694
# 60                  63    684
# 62                  65    669
# 59                  62    646
# 63                  66    630
# ..                 ...    ...
# 615                955      1
# 616               1174      1
# 617               1175      1
# 618               1182      1
# 619               1442      1
#
# [620 rows x 2 columns]

# %%
# Combine all reviews into one string, split into words
all_words = ' '.join(cleaned_data['review']).split()

# Count frequency of each word
word_counts = Counter(all_words)

# Convert to DataFrame for easy viewing
word_counts_df = pd.DataFrame(word_counts.items(), columns=['word', 'count']).sort_values(by='count', ascending=False)
word_counts_df.head(50) # Show top 20 most common words
# Out:
#            word   count
# 10           br  200400
# 273       movie  102484
# 283        film   92812
# 0           one   55032
# 291        like   40786
# 141        time   31205
# 366        good   29656
# 216   character   28119
# 388       story   25110
# 218        even   24666
# 114         get   24465
# 77        would   24400
# 282        make   24045
# 161         see   23861
# 178      really   22921
# 16        scene   21298
# 115        well   21280
# 608        much   19152
# 486         bad   18290
# 322      people   18201
# 174       great   18096
# 498        also   17850
# 11        first   17436
# 22         show   17144
# 202         way   17090
# 12        thing   16365
# 511        made   16003
# 177        life   15514
# 823       could   15421
# 268       think   15120
# 20           go   14623
# 342        know   14223
# 311       watch   14066
# 238        love   13726
# 212        plot   13522
# 152       actor   13486
# 1471        two   13429
# 59         many   13360
# 397        seen   13265
# 240        year   13166
# 78          say   12927
# 535         end   12906
# 74        never   12880
# 365      acting   12767
# 348        look   12723
# 358        best   12555
# 135      little   12322
# 94         ever   11939
# 777         man   11825
# 577      better   11345

# %%
word_counts_df['count'].describe()
# Out:
# count     89823.000000
# mean         67.501008
# std         996.628085
# min           1.000000
# 25%           1.000000
# 50%           2.000000
# 75%          12.000000
# max      200400.000000
# Name: count, dtype: float64

# %%
word_count_distribution = (
    word_counts_df.groupby('count')
    .size()
    .reset_index(name='groupby_count')
    .sort_values(by='count', ascending=False)
)
word_count_distribution
# Out:
#        count  groupby_count
# 1729  200400              1
# 1728  102484              1
# 1727   92812              1
# 1726   55032              1
# 1725   40786              1
# ...      ...            ...
# 4          5           2854
# 3          4           3885
# 2          3           5820
# 1          2          10481
# 0          1          34976
#
# [1730 rows x 2 columns]

# %%
# Plot the top 50 most common words as a bar chart
top_50 = word_counts_df.head(50)
plt.figure(figsize=(16, 6))
plt.bar(top_50['word'], top_50['count'])
plt.title('Top 50 Most Common Words')
plt.xlabel('Word')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
from wordcloud import WordCloud

# Generate a word cloud for the top 50 most common words
top_50_words = dict(word_counts_df.head(50).values)
wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(top_50_words)

plt.figure(figsize=(16, 8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Top 50 Most Common Words (Word Cloud)')
plt.show()

# %% [markdown]
# remove BR from cleaned_data
